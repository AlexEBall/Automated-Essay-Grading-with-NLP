# %%
import enchant 
import pandas as pd

essays = pd.read_csv('../data/intermediate/prepped_essays_df.csv')

# ----------- ISOLATE JUST ESSAYS FROM 6th SET ------------ #
essays = essays[essays['essay_set'] == 6]
essays.dropna(axis=1, how='all', inplace=True)
essays.head()
# Out:
#       essay_id  essay_set                                              essay  \
# 8886     14834          6  There were many obstacles that the builders fa...
# 8887     14835          6  Him from the start, there would have been many...
# 8888     14836          6  The builders of the Empire State Building face...
# 8889     14837          6  In the passage The Mooring Mast by Marcia Amid...
# 8890     14838          6  The builders of the Empire State Building face...
#
#       rater1_domain1  rater2_domain1  domain1_score  \
# 8886             2.0             2.0            2.0
# 8887             3.0             3.0            3.0
# 8888             3.0             4.0            4.0
# 8889             1.0             1.0            1.0
# 8890             3.0             3.0            3.0
#
#                                                  prompt  has_source_material  \
# 8886  Based on the excerpt, describe the obstacles t...                    1
# 8887  Based on the excerpt, describe the obstacles t...                    1
# 8888  Based on the excerpt, describe the obstacles t...                    1
# 8889  Based on the excerpt, describe the obstacles t...                    1
# 8890  Based on the excerpt, describe the obstacles t...                    1
#
#                                             source_text  grade_7  grade_8  \
# 8886  When the Empire State Building was conceived, ...        0        0
# 8887  When the Empire State Building was conceived, ...        0        0
# 8888  When the Empire State Building was conceived, ...        0        0
# 8889  When the Empire State Building was conceived, ...        0        0
# 8890  When the Empire State Building was conceived, ...        0        0
#
#       grade_10
# 8886         1
# 8887         1
# 8888         1
# 8889         1
# 8890         1

# %%
sample = essays.iloc[0, 2]
sample
# Out:
# "There were many obstacles that the builders faced in attempting to have dirigibles dock at the Empire State Building. Safety was an issue with the dirigibles because of the highly flammable gas hydrogen. So, if the dirigibles explode over New York many people could be killed in the very populated. Another problem is keeping the derigible @CAPS1 so people can get off while the wind moves the back end of itself. The only way was to tie lead weights down in the back of the dirigible, but it would be dangerous over people down below. So, these obstacles workers faced, never got past them and so they made the world's highest soda fountain and tea garden for tourists in the observation area."

# %%
d = enchant.Dict("en_US")
counter = []

for word in sample.split():  # Split the sentence into words and iterate through each.
#     if word[0].lower() > 'g':  # Check if the first character (lowercased) > g.
#         print(word.upper())  # If so, print the word all capitalised.
#     print(d.check(word))
    counter.append(d.check(word))
    
(counter.count(False), counter.count(True))
# Out:
# (6, 116)

# %%
# _individual_tups = []
_byRow = []

def getCorrectAndIncorrectSpelling(seriesOfEssays):
    """
    Returns a list of tuples:
    number of mispelled words, number of correctly spelled words 
    """
    _byRow = []

    for essay in seriesOfEssays:
        _individual = []
        for word in essay.split():

            _individual.append(d.check(word))

        _byRow.append((_individual.count(False), _individual.count(True)))

    return _byRow

# %%
spellings = getCorrectAndIncorrectSpelling(essays['essay'])

# %%
spellings
# Out:
# [(6, 116),
#  (11, 169),
#  (4, 162),
#  (18, 175),
#  (4, 158),
#  (7, 161),
#  (5, 143),
#  (18, 110),
#  (4, 110),
#  (5, 125),
#  (14, 219),
#  (26, 286),
#  (7, 206),
#  (18, 177),
#  (9, 126),
#  (21, 131),
#  (8, 133),
#  (5, 121),
#  (5, 82),
#  (2, 86),
#  (6, 108),
#  (19, 225),
#  (14, 163),
#  (11, 222),
#  (7, 109),
#  (16, 151),
#  (11, 199),
#  (14, 184),
#  (13, 146),
#  (3, 106),
#  (12, 157),
#  (6, 169),
#  (3, 60),
#  (2, 100),
#  (11, 193),
#  (8, 138),
#  (7, 123),
#  (4, 130),
#  (10, 134),
#  (0, 111),
#  (4, 108),
#  (12, 89),
#  (18, 180),
#  (4, 96),
#  (16, 119),
#  (13, 116),
#  (17, 141),
#  (18, 176),
#  (17, 207),
#  (19, 203),
#  (11, 138),
#  (16, 170),
#  (8, 156),
#  (9, 170),
#  (11, 163),
#  (12, 157),
#  (7, 160),
#  (8, 123),
#  (19, 181),
#  (9, 75),
#  (13, 173),
#  (16, 145),
#  (15, 245),
#  (17, 160),
#  (6, 185),
#  (1, 103),
#  (6, 130),
#  (1, 31),
#  (9, 203),
#  (19, 144),
#  (30, 167),
#  (3, 71),
#  (14, 98),
#  (6, 110),
#  (19, 127),
#  (7, 135),
#  (5, 81),
#  (6, 59),
#  (13, 96),
#  (20, 161),
#  (5, 125),
#  (5, 136),
#  (16, 183),
#  (7, 170),
#  (8, 178),
#  (3, 102),
#  (1, 37),
#  (2, 49),
#  (21, 175),
#  (8, 182),
#  (1, 36),
#  (17, 191),
#  (3, 53),
#  (10, 117),
#  (13, 110),
#  (18, 143),
#  (4, 106),
#  (7, 131),
#  (29, 219),
#  (7, 111),
#  (16, 158),
#  (11, 140),
#  (16, 175),
#  (13, 137),
#  (23, 246),
#  (1, 83),
#  (5, 92),
#  (7, 160),
#  (15, 164),
#  (21, 161),
#  (11, 190),
#  (21, 172),
#  (20, 148),
#  (15, 208),
#  (6, 115),
#  (1, 74),
#  (12, 110),
#  (15, 240),
#  (23, 217),
#  (14, 152),
#  (12, 170),
#  (6, 137),
#  (19, 146),
#  (18, 161),
#  (20, 205),
#  (29, 207),
#  (9, 153),
#  (17, 168),
#  (5, 111),
#  (3, 115),
#  (10, 85),
#  (26, 184),
#  (5, 135),
#  (13, 166),
#  (6, 51),
#  (6, 102),
#  (11, 107),
#  (16, 175),
#  (10, 116),
#  (2, 120),
#  (6, 147),
#  (10, 165),
#  (14, 148),
#  (3, 143),
#  (5, 68),
#  (9, 121),
#  (6, 119),
#  (17, 121),
#  (2, 81),
#  (4, 127),
#  (16, 142),
#  (21, 152),
#  (9, 127),
#  (19, 147),
#  (10, 143),
#  (9, 90),
#  (15, 142),
#  (16, 112),
#  (7, 192),
#  (11, 155),
#  (2, 28),
#  (28, 367),
#  (16, 129),
#  (4, 149),
#  (12, 226),
#  (5, 131),
#  (7, 122),
#  (3, 145),
#  (2, 33),
#  (7, 76),
#  (4, 85),
#  ...]

# %%
list1, list2 = zip(*spellings)

# %%
list1
# Out:
# (6,
#  11,
#  4,
#  18,
#  4,
#  7,
#  5,
#  18,
#  4,
#  5,
#  14,
#  26,
#  7,
#  18,
#  9,
#  21,
#  8,
#  5,
#  5,
#  2,
#  6,
#  19,
#  14,
#  11,
#  7,
#  16,
#  11,
#  14,
#  13,
#  3,
#  12,
#  6,
#  3,
#  2,
#  11,
#  8,
#  7,
#  4,
#  10,
#  0,
#  4,
#  12,
#  18,
#  4,
#  16,
#  13,
#  17,
#  18,
#  17,
#  19,
#  11,
#  16,
#  8,
#  9,
#  11,
#  12,
#  7,
#  8,
#  19,
#  9,
#  13,
#  16,
#  15,
#  17,
#  6,
#  1,
#  6,
#  1,
#  9,
#  19,
#  30,
#  3,
#  14,
#  6,
#  19,
#  7,
#  5,
#  6,
#  10,
#  18,
#  11,
#  5,
#  9,
#  15,
#  5,
#  11,
#  12,
#  15,
#  14,
#  11,
#  14,
#  23,
#  16,
#  7,
#  9,
#  7,
#  3,
#  6,
#  5,
#  9,
#  22,
#  4,
#  2,
#  8,
#  7,
#  6,
#  10,
#  10,
#  19,
#  16,
#  17,
#  4,
#  8,
#  21,
#  8,
#  8,
#  14,
#  9,
#  4,
#  14,
#  17,
#  6,
#  41,
#  1,
#  4,
#  22,
#  18,
#  15,
#  17,
#  7,
#  7,
#  4,
#  19,
#  17,
#  12,
#  3,
#  11,
#  12,
#  11,
#  6,
#  2,
#  24,
#  10,
#  13,
#  31,
#  7,
#  14,
#  13,
#  17,
#  8,
#  14,
#  14,
#  3,
#  7,
#  10,
#  4,
#  28,
#  5,
#  2,
#  5,
#  27,
#  23,
#  5,
#  4,
#  18,
#  10,
#  25,
#  11,
#  6,
#  6,
#  29,
#  7,
#  19,
#  7,
#  15,
#  13,
#  2,
#  25,
#  8,
#  1,
#  6,
#  3,
#  3,
#  1,
#  2,
#  27,
#  14,
#  10,
#  17,
#  13,
#  5,
#  2,
#  12,
#  8,
#  2,
#  14,
#  7,
#  15,
#  10,
#  8,
#  32,
#  9,
#  15,
#  5,
#  9,
#  10,
#  8,
#  3,
#  7,
#  18,
#  13,
#  4,
#  15,
#  12,
#  9,
#  14,
#  16,
#  6,
#  20,
#  12,
#  5,
#  7,
#  2,
#  3,
#  14,
#  21,
#  8,
#  6,
#  20,
#  23,
#  13,
#  2,
#  4,
#  1,
#  18,
#  14,
#  3,
#  4,
#  5,
#  18,
#  9,
#  11,
#  8,
#  8,
#  0,
#  6,
#  4,
#  13,
#  19,
#  17,
#  2,
#  41,
#  1,
#  21,
#  12,
#  15,
#  10,
#  14,
#  12,
#  7,
#  12,
#  8,
#  1,
#  8,
#  7,
#  13,
#  10,
#  19,
#  14,
#  14,
#  7,
#  19,
#  21,
#  8,
#  18,
#  7,
#  5,
#  10,
#  1,
#  0,
#  0,
#  6,
#  11,
#  7,
#  7,
#  9,
#  3,
#  11,
#  8,
#  11,
#  22,
#  3,
#  3,
#  14,
#  13,
#  4,
#  8,
#  14,
#  15,
#  7,
#  5,
#  19,
#  14,
#  30,
#  12,
#  24,
#  7,
#  3,
#  6,
#  10,
#  1,
#  16,
#  1,
#  8,
#  1,
#  10,
#  7,
#  29,
#  17,
#  13,
#  9,
#  3,
#  19,
#  12,
#  11,
#  22,
#  6,
#  14,
#  17,
#  6,
#  8,
#  5,
#  22,
#  11,
#  13,
#  19,
#  12,
#  11,
#  13,
#  11,
#  17,
#  17,
#  12,
#  10,
#  4,
#  16,
#  20,
#  20,
#  12,
#  5,
#  5,
#  2,
#  15,
#  9,
#  5,
#  16,
#  6,
#  6,
#  6,
#  4,
#  1,
#  7,
#  8,
#  15,
#  11,
#  15,
#  13,
#  2,
#  1,
#  27,
#  5,
#  27,
#  2,
#  9,
#  16,
#  14,
#  9,
#  9,
#  0,
#  13,
#  2,
#  28,
#  5,
#  3,
#  2,
#  8,
#  13,
#  2,
#  14,
#  11,
#  11,
#  16,
#  15,
#  5,
#  14,
#  2,
#  8,
#  5,
#  7,
#  14,
#  18,
#  7,
#  6,
#  17,
#  5,
#  11,
#  3,
#  10,
#  15,
#  12,
#  14,
#  3,
#  11,
#  10,
#  3,
#  11,
#  9,
#  1,
#  10,
#  12,
#  8,
#  7,
#  27,
#  11,
#  3,
#  16,
#  4,
#  11,
#  13,
#  5,
#  19,
#  19,
#  18,
#  11,
#  1,
#  3,
#  15,
#  3,
#  7,
#  12,
#  14,
#  4,
#  16,
#  26,
#  0,
#  4,
#  12,
#  3,
#  13,
#  10,
#  11,
#  29,
#  10,
#  25,
#  8,
#  16,
#  2,
#  27,
#  14,
#  5,
#  9,
#  10,
#  10,
#  9,
#  4,
#  2,
#  24,
#  11,
#  19,
#  16,
#  2,
#  7,
#  13,
#  4,
#  15,
#  13,
#  15,
#  3,
#  6,
#  19,
#  4,
#  15,
#  3,
#  26,
#  39,
#  1,
#  21,
#  8,
#  17,
#  19,
#  6,
#  4,
#  11,
#  11,
#  10,
#  9,
#  11,
#  17,
#  7,
#  12,
#  12,
#  9,
#  11,
#  17,
#  1,
#  6,
#  6,
#  20,
#  6,
#  4,
#  21,
#  14,
#  9,
#  10,
#  6,
#  2,
#  10,
#  16,
#  18,
#  11,
#  18,
#  6,
#  12,
#  4,
#  12,
#  4,
#  23,
#  3,
#  4,
#  3,
#  22,
#  10,
#  6,
#  8,
#  17,
#  26,
#  5,
#  3,
#  19,
#  25,
#  10,
#  13,
#  13,
#  1,
#  13,
#  15,
#  13,
#  4,
#  19,
#  12,
#  14,
#  11,
#  6,
#  18,
#  11,
#  18,
#  3,
#  15,
#  9,
#  5,
#  22,
#  10,
#  24,
#  23,
#  20,
#  8,
#  7,
#  7,
#  8,
#  8,
#  23,
#  11,
#  6,
#  3,
#  18,
#  18,
#  3,
#  16,
#  0,
#  17,
#  2,
#  15,
#  23,
#  12,
#  6,
#  10,
#  8,
#  11,
#  7,
#  14,
#  10,
#  3,
#  4,
#  12,
#  13,
#  6,
#  17,
#  9,
#  13,
#  11,
#  3,
#  27,
#  16,
#  7,
#  5,
#  6,
#  20,
#  1,
#  20,
#  10,
#  7,
#  8,
#  6,
#  19,
#  4,
#  5,
#  24,
#  4,
#  5,
#  5,
#  6,
#  6,
#  10,
#  25,
#  11,
#  20,
#  11,
#  10,
#  16,
#  2,
#  14,
#  0,
#  9,
#  18,
#  4,
#  16,
#  19,
#  18,
#  2,
#  9,
#  5,
#  12,
#  24,
#  11,
#  25,
#  7,
#  0,
#  5,
#  8,
#  7,
#  13,
#  12,
#  12,
#  1,
#  5,
#  15,
#  12,
#  19,
#  11,
#  29,
#  38,
#  14,
#  5,
#  16,
#  7,
#  23,
#  16,
#  9,
#  5,
#  12,
#  2,
#  4,
#  10,
#  8,
#  15,
#  8,
#  15,
#  5,
#  32,
#  2,
#  0,
#  13,
#  17,
#  7,
#  9,
#  11,
#  14,
#  23,
#  11,
#  24,
#  11,
#  7,
#  16,
#  3,
#  8,
#  6,
#  22,
#  10,
#  3,
#  10,
#  28,
#  16,
#  3,
#  9,
#  8,
#  8,
#  9,
#  11,
#  12,
#  18,
#  20,
#  10,
#  6,
#  16,
#  7,
#  17,
#  10,
#  6,
#  8,
#  5,
#  10,
#  20,
#  6,
#  18,
#  7,
#  0,
#  11,
#  18,
#  14,
#  4,
#  9,
#  3,
#  12,
#  11,
#  3,
#  4,
#  0,
#  3,
#  7,
#  14,
#  16,
#  16,
#  11,
#  9,
#  26,
#  7,
#  11,
#  11,
#  9,
#  11,
#  8,
#  8,
#  25,
#  15,
#  6,
#  4,
#  5,
#  4,
#  18,
#  14,
#  1,
#  13,
#  2,
#  13,
#  17,
#  16,
#  6,
#  13,
#  2,
#  33,
#  4,
#  12,
#  14,
#  14,
#  9,
#  0,
#  24,
#  4,
#  15,
#  16,
#  8,
#  12,
#  2,
#  15,
#  10,
#  14,
#  14,
#  18,
#  11,
#  10,
#  26,
#  8,
#  10,
#  8,
#  4,
#  15,
#  1,
#  13,
#  14,
#  13,
#  22,
#  20,
#  4,
#  5,
#  6,
#  19,
#  22,
#  17,
#  5,
#  11,
#  8,
#  8,
#  5,
#  13,
#  7,
#  2,
#  3,
#  15,
#  21,
#  21,
#  4,
#  14,
#  22,
#  3,
#  11,
#  2,
#  7,
#  8,
#  15,
#  0,
#  7,
#  9,
#  8,
#  27,
#  1,
#  11,
#  7,
#  13,
#  2,
#  3,
#  18,
#  10,
#  18,
#  7,
#  3,
#  10,
#  6,
#  17,
#  13,
#  13,
#  13,
#  8,
#  3,
#  16,
#  8,
#  19,
#  1,
#  3,
#  21,
#  8,
#  11,
#  15,
#  5,
#  17,
#  9,
#  24,
#  11,
#  3,
#  19,
#  9,
#  4,
#  21,
#  22,
#  18,
#  15,
#  3,
#  4,
#  15,
#  4,
#  23,
#  22,
#  14,
#  2,
#  7,
#  12,
#  6,
#  7,
#  28,
#  16,
#  0,
#  25,
#  5,
#  6,
#  9,
#  1,
#  18,
#  3,
#  7,
#  9,
#  4,
#  13,
#  9,
#  12,
#  7,
#  7,
#  6,
#  13,
#  13,
#  20,
#  5,
#  5,
#  16,
#  7,
#  8,
#  3,
#  1,
#  2,
#  21,
#  8,
#  1,
#  17,
#  3,
#  10,
#  13,
#  18,
#  4,
#  7,
#  29,
#  7,
#  16,
#  11,
#  16,
#  13,
#  23,
#  1,
#  5,
#  7,
#  15,
#  21,
#  11,
#  21,
#  20,
#  15,
#  6,
#  1,
#  12,
#  15,
#  23,
#  14,
#  12,
#  6,
#  19,
#  18,
#  20,
#  29,
#  9,
#  17,
#  5,
#  3,
#  10,
#  26,
#  5,
#  13,
#  6,
#  6,
#  11,
#  16,
#  10,
#  2,
#  6,
#  10,
#  14,
#  3,
#  5,
#  9,
#  6,
#  17,
#  2,
#  4,
#  16,
#  21,
#  9,
#  19,
#  10,
#  9,
#  15,
#  16,
#  7,
#  11,
#  2,
#  28,
#  16,
#  4,
#  12,
#  5,
#  7,
#  3,
#  2,
#  7,
#  4,
#  ...)

# %%
# Using 'Address' as the column name and equating it to the list 
df2 = essays.assign(misspelt = list1) 
   
# Observe the result 
df2.head()
# Out:
#       essay_id  essay_set                                              essay  \
# 8886     14834          6  There were many obstacles that the builders fa...
# 8887     14835          6  Him from the start, there would have been many...
# 8888     14836          6  The builders of the Empire State Building face...
# 8889     14837          6  In the passage The Mooring Mast by Marcia Amid...
# 8890     14838          6  The builders of the Empire State Building face...
#
#       rater1_domain1  rater2_domain1  domain1_score  \
# 8886             2.0             2.0            2.0
# 8887             3.0             3.0            3.0
# 8888             3.0             4.0            4.0
# 8889             1.0             1.0            1.0
# 8890             3.0             3.0            3.0
#
#                                                  prompt  has_source_material  \
# 8886  Based on the excerpt, describe the obstacles t...                    1
# 8887  Based on the excerpt, describe the obstacles t...                    1
# 8888  Based on the excerpt, describe the obstacles t...                    1
# 8889  Based on the excerpt, describe the obstacles t...                    1
# 8890  Based on the excerpt, describe the obstacles t...                    1
#
#                                             source_text  grade_7  grade_8  \
# 8886  When the Empire State Building was conceived, ...        0        0
# 8887  When the Empire State Building was conceived, ...        0        0
# 8888  When the Empire State Building was conceived, ...        0        0
# 8889  When the Empire State Building was conceived, ...        0        0
# 8890  When the Empire State Building was conceived, ...        0        0
#
#       grade_10  misspelt
# 8886         1         6
# 8887         1        11
# 8888         1         4
# 8889         1        18
# 8890         1         4

# %%
essays = df2.assign(correct = list2)

# %%
essays.head()
# Out:
#       essay_id  essay_set                                              essay  \
# 8886     14834          6  There were many obstacles that the builders fa...
# 8887     14835          6  Him from the start, there would have been many...
# 8888     14836          6  The builders of the Empire State Building face...
# 8889     14837          6  In the passage The Mooring Mast by Marcia Amid...
# 8890     14838          6  The builders of the Empire State Building face...
#
#       rater1_domain1  rater2_domain1  domain1_score  \
# 8886             2.0             2.0            2.0
# 8887             3.0             3.0            3.0
# 8888             3.0             4.0            4.0
# 8889             1.0             1.0            1.0
# 8890             3.0             3.0            3.0
#
#                                                  prompt  has_source_material  \
# 8886  Based on the excerpt, describe the obstacles t...                    1
# 8887  Based on the excerpt, describe the obstacles t...                    1
# 8888  Based on the excerpt, describe the obstacles t...                    1
# 8889  Based on the excerpt, describe the obstacles t...                    1
# 8890  Based on the excerpt, describe the obstacles t...                    1
#
#                                             source_text  grade_7  grade_8  \
# 8886  When the Empire State Building was conceived, ...        0        0
# 8887  When the Empire State Building was conceived, ...        0        0
# 8888  When the Empire State Building was conceived, ...        0        0
# 8889  When the Empire State Building was conceived, ...        0        0
# 8890  When the Empire State Building was conceived, ...        0        0
#
#       grade_10  misspelt  correct
# 8886         1         6      116
# 8887         1        11      169
# 8888         1         4      162
# 8889         1        18      175
# 8890         1         4      158

# %%
from nltk import word_tokenize
tokens = word_tokenize(sample)

# %%
len(tokens)
# set(tokens)
# len(set(tokens))
# tokens.count('wub')
# tokens.count('the')
# 100 * tokens.count('wub') / float(len(tokens))
# 100 * tokens.count('the') / float(len(tokens))
# Out:
# 134

# %%
sample
# Out:
# "There were many obstacles that the builders faced in attempting to have dirigibles dock at the Empire State Building. Safety was an issue with the dirigibles because of the highly flammable gas hydrogen. So, if the dirigibles explode over New York many people could be killed in the very populated. Another problem is keeping the derigible @CAPS1 so people can get off while the wind moves the back end of itself. The only way was to tie lead weights down in the back of the dirigible, but it would be dangerous over people down below. So, these obstacles workers faced, never got past them and so they made the world's highest soda fountain and tea garden for tourists in the observation area."

# %%
# using split() 
# to count words in string 
res = len(sample.split()) 
res
# Out:
# 122

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
# text = "This is my text. It icludes commas, question marks? and other stuff. Also U.S.."
tokens = tokenizer.tokenize(sample)

# %%
# number of words in essay
len(tokens)
# Out:
# 123

# %%
# unique words
len(set(tokens))
# Out:
# 90

# %% [markdown]
# 10.7.1. How to measure lexical diversity
# One simple statistic for a text is to find the ratio of total words to unique words, or word tokens divided by word types. This is simple enough for you to calculate – with the caveat of insuring real number (float) division – as long as you filter out the punctuation. Oh, and you should round the resulting floating point numbers to two decimal places, otherwise Python returns it to fourteen decimal places:

# %%
# lexical diversity
lD = len(tokens) / float(len(set(tokens)))
round(lD, 2)
# Out:
# 1.37

# %% [markdown]
# Now you might suspect that the lexical diversity of text could be proportional to how long the text is. The longer the text, the greater the chance for the author to use words that she has not used yet. You can test this hypothesis by plotting lexical diversity against the length of the texts. That, the length of the texts is the independent variable, on the X axis, against which you want to evaluate the lexical diversity of a text, the dependent variable on the Y axis. As the terminology suggests, the dependent variable depends on the independent one, which is shown quantitatively by plotting Y onto X.

# %%
import spacy
nlp = spacy.load('en_core_web_md')
parsed_essay = nlp(sample)

# %%
# number of sentences
for num, sentence in enumerate(parsed_essay.sents):
    print('Sentence {}:'.format(num + 1))
    print(sentence)
    print('')
# Out:
# Sentence 1:
# There were many obstacles that the builders faced in attempting to have dirigibles dock at the Empire State Building.
#
# Sentence 2:
# Safety was an issue with the dirigibles because of the highly flammable gas hydrogen.
#
# Sentence 3:
# So, if the dirigibles explode over New York
#
# Sentence 4:
# many people could be killed in the very populated.
#
# Sentence 5:
# Another problem is keeping the derigible @CAPS1
#
# Sentence 6:
# so people can get off while the wind moves the back end of itself.
#
# Sentence 7:
# The only way was to tie lead weights down in the back of the dirigible, but it would be dangerous over people down below.
#
# Sentence 8:
# So, these obstacles workers faced, never got past them
#
# Sentence 9:
# and so they made the world's highest soda fountain and tea garden for tourists in the observation area.

# %%
for num, entity in enumerate(parsed_essay.ents):
    print('Entity {}:'.format(num + 1), entity, '-', entity.label_)
    print('')
# Out:
# Entity 1: the Empire State Building - FAC
#
# Entity 2: New York - GPE

# %%
# number of parts of speech
token_pos = [token.pos_ for token in parsed_essay]

# %%
token_pos.count('ADV')
# Out:
# 9

# %%
import urllib.request
from bs4 import BeautifulSoup

f = open('../data/intermediate/out.txt','w')

url = "https://satvocabulary.us/"
page = urllib.request.urlopen(url)

soup = BeautifulSoup(page)

# %%
soup.unicode

# %%
import re
regex = re.compile(".*?\((.*?)\)")
result = re.sub("[\(\[].*?[\)\]]", "", 'venal(ity)')

tab = soup.find("table",{"class":"WORDLIST"})
# tab
rows = tab.find_all('tr')
rows

top500SATWords = []

for row in rows:
    data = row.find_all("td")
    
    top500SATWords.append(re.sub("[\(\[].*?[\)\]]", "", ((data[1].get_text()).split(', ')[0])))

# top500SATWords

# %%
# token_lemma_punct = [(token.lemma_, token.is_punct for token in parsed_essay)]
# token_lemma_punct


# token_attributes = [(token.orth_,
#                      token.lemma,
#                      token.is_stop,
#                      token.is_punct for token in parsed_essay)]


token_attributes = [(token.orth_, token.is_stop, token.is_punct) for token in parsed_essay]

# %%
df = pd.DataFrame(token_attributes,
                  columns=['text',
                           'stop',
                           'punctuation'])

# s1 = pd.Series(['X0', 'X1', 'X2', 'X3'], name='X')

# In [19]: result = pd.concat([df1, s1], axis=1)

df3 = df[df['stop'] != True]

# df4 = df[df['punctuation'] != True]

# df.head()

# df4 df.

# print(len(df))

# print(len(df3))
df4 = df3[df3['punctuation'] == False]
len(df4)
# Out:
# 52

# %%
low = df4['text'].tolist()

# %%
low  = [word.lower() for word in low]

# %%
low
# Out:
# ['obstacles',
#  'builders',
#  'faced',
#  'attempting',
#  'dirigibles',
#  'dock',
#  'empire',
#  'state',
#  'building',
#  'safety',
#  'issue',
#  'dirigibles',
#  'highly',
#  'flammable',
#  'gas',
#  'hydrogen',
#  'dirigibles',
#  'explode',
#  'new',
#  'york',
#  'people',
#  'killed',
#  'populated',
#  'problem',
#  'keeping',
#  'derigible',
#  '@caps1',
#  'people',
#  'wind',
#  'moves',
#  'end',
#  'way',
#  'tie',
#  'lead',
#  'weights',
#  'dirigible',
#  'dangerous',
#  'people',
#  'obstacles',
#  'workers',
#  'faced',
#  'got',
#  'past',
#  'world',
#  'highest',
#  'soda',
#  'fountain',
#  'tea',
#  'garden',
#  'tourists',
#  'observation',
#  'area']

# %%
low_joined = ' '.join(str(v) for v in low)

# %%
token_lemma = [token.lemma_ for token in nlp(low_joined)]

# %%
token_lemma
# Out:
# ['obstacle',
#  'builder',
#  'face',
#  'attempt',
#  'dirigible',
#  'dock',
#  'empire',
#  'state',
#  'building',
#  'safety',
#  'issue',
#  'dirigible',
#  'highly',
#  'flammable',
#  'gas',
#  'hydrogen',
#  'dirigible',
#  'explode',
#  'new',
#  'york',
#  'people',
#  'kill',
#  'populated',
#  'problem',
#  'keep',
#  'derigible',
#  '@caps1',
#  'people',
#  'wind',
#  'move',
#  'end',
#  'way',
#  'tie',
#  'lead',
#  'weight',
#  'dirigible',
#  'dangerous',
#  'people',
#  'obstacles',
#  'worker',
#  'face',
#  'get',
#  'past',
#  'world',
#  'high',
#  'soda',
#  'fountain',
#  'tea',
#  'garden',
#  'tourist',
#  'observation',
#  'area']

# %%
top500SATWords.pop(0)
top500SATWords

# %%
top500_joined = ' '.join(str(v) for v in top500SATWords)

# %%
token_lemma_top500 = [token.lemma_ for token in nlp(top500_joined)]

# %%
token_lemma_top500

# %%
print(len(token_lemma))
print(len(token_lemma_top500))
# Out:
# 52
# 512

# %%
list1 = ['car', 'garden', 'cement', 'chicken']
list2 = ['automobile', 'nest', 'cementry', 'house']

c = sum(el in list1 for el in list2)
c
# Out:
# 0

# %%
n_top500SAT = sum(el in token_lemma for el in token_lemma_top500)

# %%
n_top500SAT
# Out:
# 0

# %%
sample
parsed_essay = nlp(sample)

# print(sorted(list(set(top500SATWords))))
# print(parsed_essay)

# print(set(parsed_essay))

def calculate_number_of_top500_SAT_words(parsed_essay, list_of_word_to_check_against):
    list_of_word_to_check_against = sorted(list(set(list_of_word_to_check_against)))
    token_attributes = [(token.lemma_, token.is_stop, token.is_punct) for token in parsed_essay]
    
    df = pd.DataFrame(token_attributes, columns=['text', 'stop', 'punctuation'])
    df2 = df[df['stop'] != True]
    df3 = df2[df2['punctuation'] != True]
    
    low = df3['text'].tolist()
    low  = [word.lower() for word in low]
    
    count = sum(el in low for el in list_of_word_to_check_against)
    return count

# %%
calculate_number_of_top500_SAT_words(set(parsed_essay), token_lemma_top500)
# Out:
# 0

# %%
# print(token_lemma_top500)

# %%
# print(set(list1))
# print(bool(set(list1) & set(list2)))

# %%
# smth = set(list1) & set(list2)

# %%
# smth

# %%
def buildDFSAT(df):
    n_top500 = []
    for essay in df['essay']:
        
        parsed_essay = nlp(essay)
        n_top500.append(calculate_number_of_top500_SAT_words(parsed_essay, token_lemma_top500))        
    
    essays = df.assign(n_top500 = n_top500) 
    return essays
        
essays = buildDFSAT(essays)

# %%
essays

# %%
# set(top500SATWords)

# %%
# sample2 = essays[essays['essay_id'] == 14856]

# %%
# sample2 = sample2['essay']

# %%
essays[essays['n_top500'] > 1]
# Out:
#        essay_id  essay_set                                              essay  \
# 9053      15001          6  Ambitious for its time, the idea of allowing d...
# 9463      15411          6  In attempting to allow dirigibles to dock at t...
# 9779      15727          6  The @CAPS1 of the Empire State Building faced ...
# 9825      15773          6  In the excerpt, The Mooring Mast by @ORGANIZAT...
# 9876      15824          6  The idea of using a mooring mast in order to a...
# 10034     15982          6  The Empire State Building was built as the tal...
# 10349     16297          6  . The Empire State Building during it's constr...
# 10516     16464          6  The first obstacle that the can builders faced...
#
#        rater1_domain1  rater2_domain1  domain1_score  \
# 9053              3.0             3.0            3.0
# 9463              3.0             4.0            4.0
# 9779              1.0             2.0            2.0
# 9825              2.0             2.0            2.0
# 9876              4.0             3.0            4.0
# 10034             3.0             3.0            3.0
# 10349             3.0             3.0            3.0
# 10516             2.0             2.0            2.0
#
#                                                   prompt  has_source_material  \
# 9053   Based on the excerpt, describe the obstacles t...                    1
# 9463   Based on the excerpt, describe the obstacles t...                    1
# 9779   Based on the excerpt, describe the obstacles t...                    1
# 9825   Based on the excerpt, describe the obstacles t...                    1
# 9876   Based on the excerpt, describe the obstacles t...                    1
# 10034  Based on the excerpt, describe the obstacles t...                    1
# 10349  Based on the excerpt, describe the obstacles t...                    1
# 10516  Based on the excerpt, describe the obstacles t...                    1
#
#                                              source_text  grade_7  grade_8  \
# 9053   When the Empire State Building was conceived, ...        0        0
# 9463   When the Empire State Building was conceived, ...        0        0
# 9779   When the Empire State Building was conceived, ...        0        0
# 9825   When the Empire State Building was conceived, ...        0        0
# 9876   When the Empire State Building was conceived, ...        0        0
# 10034  When the Empire State Building was conceived, ...        0        0
# 10349  When the Empire State Building was conceived, ...        0        0
# 10516  When the Empire State Building was conceived, ...        0        0
#
#        grade_10  misspelt  correct  n_top500
# 9053          1        11      164         2
# 9463          1        16      177         2
# 9779          1         9      113         2
# 9825          1        11      190         2
# 9876          1        28      367         2
# 10034         1        14      214         2
# 10349         1        15      169         2
# 10516         1        14      155         2

# %%
sample2 = essays[essays['n_top500'] > 1].iloc[2, 2]
sample2
# Out:
# "The @CAPS1 of the Empire State Building faced many obstacles. By allowing the dirigibles to dock there, They had to build @CAPS2 planfronts on the side of the building, which means that they would be putting there life's in danger. They also had to deal with the electrical  problems within and without the building. The @CAPS1 on the outsides of the building would have to deal with the strong wind currents. They also have to make sure that the electrical system was working properly. If there were to be a stark of any sort of Fire, the hydrogen and helium were extremely flameable, and if a wire were too short, it could like the whole dirigible aflame and it would blow up."

# %%
calculate_number_of_top500_SAT_words(nlp(sample2), token_lemma_top500)
# Out:
# 2

# %%
# token_lemma_top500

# %%
# token_attributes = [(token.lemma_, token.is_stop, token.is_punct) for token in nlp(sample2)]
    
# df = pd.DataFrame(token_attributes, columns=['text', 'stop', 'punctuation'])
# df2 = df[df['stop'] != True]
# df3 = df2[df2['punctuation'] != True]

# low = df3['text'].tolist()
# low  = [word.lower() for word in low]

# low

# %%
# count = sum(el in low for el in token_lemma_top500)
# count

# %% [markdown]
# Fragments
# The sentences you have encountered so far have been independent clauses. As you look more closely at your past writing assignments, you may notice that some of your sentences are not complete. A sentence that is missing a subject or a verb is called a fragment. A fragment may include a description or may express part of an idea, but it does not express a complete thought.
#
# Fragment: Children helping in the kitchen.
#
# Complete sentence: Children helping in the kitchen often make a mess.
#
# You can easily fix a fragment by adding the missing subject or verb. In the example, the sentence was missing a verb. Adding often make a mess creates an S-V-N sentence structure.
#
# Figure 1.1 Editing Fragments That Are Missing a Subject or a Verb
#
#
#
# See whether you can identify what is missing in the following fragments.
#
# Fragment: Told her about the broken vase.
#
# Complete sentence: I told her about the broken vase.
#
# Fragment: The store down on Main Street.
#
# Complete sentence: The store down on Main Street sells music.
