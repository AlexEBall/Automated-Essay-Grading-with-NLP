# %%
import enchant 
import pandas as pd

essays = pd.read_csv('../data/intermediate/prepped_essays_df.csv')

# ----------- ISOLATE JUST ESSAYS FROM 6th SET ------------ #
essays = essays[essays['essay_set'] == 6]
essays.dropna(axis=1, how='all', inplace=True)
essays.head()
# Out:
#       essay_id  essay_set                                              essay  \
# 8886     14834          6  There were many obstacles that the builders fa...
# 8887     14835          6  Him from the start, there would have been many...
# 8888     14836          6  The builders of the Empire State Building face...
# 8889     14837          6  In the passage The Mooring Mast by Marcia Amid...
# 8890     14838          6  The builders of the Empire State Building face...
#
#       rater1_domain1  rater2_domain1  domain1_score  \
# 8886             2.0             2.0            2.0
# 8887             3.0             3.0            3.0
# 8888             3.0             4.0            4.0
# 8889             1.0             1.0            1.0
# 8890             3.0             3.0            3.0
#
#                                                  prompt  has_source_material  \
# 8886  Based on the excerpt, describe the obstacles t...                    1
# 8887  Based on the excerpt, describe the obstacles t...                    1
# 8888  Based on the excerpt, describe the obstacles t...                    1
# 8889  Based on the excerpt, describe the obstacles t...                    1
# 8890  Based on the excerpt, describe the obstacles t...                    1
#
#                                             source_text  grade_7  grade_8  \
# 8886  When the Empire State Building was conceived, ...        0        0
# 8887  When the Empire State Building was conceived, ...        0        0
# 8888  When the Empire State Building was conceived, ...        0        0
# 8889  When the Empire State Building was conceived, ...        0        0
# 8890  When the Empire State Building was conceived, ...        0        0
#
#       grade_10
# 8886         1
# 8887         1
# 8888         1
# 8889         1
# 8890         1

# %%
d = enchant.Dict("en_US")

# %%
def getCorrectAndIncorrectSpelling(seriesOfEssays):
    """
    Returns a list of tuples:
    number of mispelled words, number of correctly spelled words 
    """
    _byRow = []

    for essay in seriesOfEssays:
        _individual = []
        for word in essay.split():

            _individual.append(d.check(word))

        _byRow.append((_individual.count(False), _individual.count(True)))

    return _byRow

# %%
spellings = getCorrectAndIncorrectSpelling(essays['essay'])

# %%
list1, list2 = zip(*spellings)

# %%
essays = essays.assign(misspelt = list1) 
   
# Observe the result 
# essays.head()
# Out:
#       essay_id  essay_set                                              essay  \
# 8886     14834          6  There were many obstacles that the builders fa...
# 8887     14835          6  Him from the start, there would have been many...
# 8888     14836          6  The builders of the Empire State Building face...
# 8889     14837          6  In the passage The Mooring Mast by Marcia Amid...
# 8890     14838          6  The builders of the Empire State Building face...
#
#       rater1_domain1  rater2_domain1  domain1_score  \
# 8886             2.0             2.0            2.0
# 8887             3.0             3.0            3.0
# 8888             3.0             4.0            4.0
# 8889             1.0             1.0            1.0
# 8890             3.0             3.0            3.0
#
#                                                  prompt  has_source_material  \
# 8886  Based on the excerpt, describe the obstacles t...                    1
# 8887  Based on the excerpt, describe the obstacles t...                    1
# 8888  Based on the excerpt, describe the obstacles t...                    1
# 8889  Based on the excerpt, describe the obstacles t...                    1
# 8890  Based on the excerpt, describe the obstacles t...                    1
#
#                                             source_text  grade_7  grade_8  \
# 8886  When the Empire State Building was conceived, ...        0        0
# 8887  When the Empire State Building was conceived, ...        0        0
# 8888  When the Empire State Building was conceived, ...        0        0
# 8889  When the Empire State Building was conceived, ...        0        0
# 8890  When the Empire State Building was conceived, ...        0        0
#
#       grade_10  misspelt
# 8886         1         6
# 8887         1        11
# 8888         1         4
# 8889         1        18
# 8890         1         4

# %%
essays = essays.assign(correct = list2)

# %%
# essays.head()
# Out:
#       essay_id  essay_set                                              essay  \
# 8886     14834          6  There were many obstacles that the builders fa...
# 8887     14835          6  Him from the start, there would have been many...
# 8888     14836          6  The builders of the Empire State Building face...
# 8889     14837          6  In the passage The Mooring Mast by Marcia Amid...
# 8890     14838          6  The builders of the Empire State Building face...
#
#       rater1_domain1  rater2_domain1  domain1_score  \
# 8886             2.0             2.0            2.0
# 8887             3.0             3.0            3.0
# 8888             3.0             4.0            4.0
# 8889             1.0             1.0            1.0
# 8890             3.0             3.0            3.0
#
#                                                  prompt  has_source_material  \
# 8886  Based on the excerpt, describe the obstacles t...                    1
# 8887  Based on the excerpt, describe the obstacles t...                    1
# 8888  Based on the excerpt, describe the obstacles t...                    1
# 8889  Based on the excerpt, describe the obstacles t...                    1
# 8890  Based on the excerpt, describe the obstacles t...                    1
#
#                                             source_text  grade_7  grade_8  \
# 8886  When the Empire State Building was conceived, ...        0        0
# 8887  When the Empire State Building was conceived, ...        0        0
# 8888  When the Empire State Building was conceived, ...        0        0
# 8889  When the Empire State Building was conceived, ...        0        0
# 8890  When the Empire State Building was conceived, ...        0        0
#
#       grade_10  misspelt  correct
# 8886         1         6      116
# 8887         1        11      169
# 8888         1         4      162
# 8889         1        18      175
# 8890         1         4      158

# %%
from nltk import word_tokenize

# %%
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')

# %%
# Number of words in essay
def get_essay_lengths(regExTokenizer, df):
    """
    Function that gets the number of words in an
    essay, not including punctuation
    """
    length = []
    for essay in df['essay']:
        length.append(len(regExTokenizer.tokenize(essay)))
        
    return df.assign(length = length)

# %%
essays = get_essay_lengths(tokenizer, essays)
# Out:
#       essay_id  essay_set                                              essay  \
# 8886     14834          6  There were many obstacles that the builders fa...
# 8887     14835          6  Him from the start, there would have been many...
# 8888     14836          6  The builders of the Empire State Building face...
# 8889     14837          6  In the passage The Mooring Mast by Marcia Amid...
# 8890     14838          6  The builders of the Empire State Building face...
#
#       rater1_domain1  rater2_domain1  domain1_score  \
# 8886             2.0             2.0            2.0
# 8887             3.0             3.0            3.0
# 8888             3.0             4.0            4.0
# 8889             1.0             1.0            1.0
# 8890             3.0             3.0            3.0
#
#                                                  prompt  has_source_material  \
# 8886  Based on the excerpt, describe the obstacles t...                    1
# 8887  Based on the excerpt, describe the obstacles t...                    1
# 8888  Based on the excerpt, describe the obstacles t...                    1
# 8889  Based on the excerpt, describe the obstacles t...                    1
# 8890  Based on the excerpt, describe the obstacles t...                    1
#
#                                             source_text  grade_7  grade_8  \
# 8886  When the Empire State Building was conceived, ...        0        0
# 8887  When the Empire State Building was conceived, ...        0        0
# 8888  When the Empire State Building was conceived, ...        0        0
# 8889  When the Empire State Building was conceived, ...        0        0
# 8890  When the Empire State Building was conceived, ...        0        0
#
#       grade_10  misspelt  correct  length
# 8886         1         6      116     123
# 8887         1        11      169     180
# 8888         1         4      162     169
# 8889         1        18      175     199
# 8890         1         4      158     162

# %%
def get_lexical_diversity(regExTokenizer, df):
    """
    Function that measures lexical diversity
    The ratio of total words to unique words
    """
    ld = []
    for essay in df['essay']:
        
        ld.append(round(len(regExTokenizer.tokenize(essay)) / float(len(set(regExTokenizer.tokenize(essay)))), 2))
    return df.assign(lexical_diversity = ld)

# %%
essays = get_lexical_diversity(tokenizer, essays)
# essays.head()
# Out:
#       essay_id  essay_set                                              essay  \
# 8886     14834          6  There were many obstacles that the builders fa...
# 8887     14835          6  Him from the start, there would have been many...
# 8888     14836          6  The builders of the Empire State Building face...
# 8889     14837          6  In the passage The Mooring Mast by Marcia Amid...
# 8890     14838          6  The builders of the Empire State Building face...
#
#       rater1_domain1  rater2_domain1  domain1_score  \
# 8886             2.0             2.0            2.0
# 8887             3.0             3.0            3.0
# 8888             3.0             4.0            4.0
# 8889             1.0             1.0            1.0
# 8890             3.0             3.0            3.0
#
#                                                  prompt  has_source_material  \
# 8886  Based on the excerpt, describe the obstacles t...                    1
# 8887  Based on the excerpt, describe the obstacles t...                    1
# 8888  Based on the excerpt, describe the obstacles t...                    1
# 8889  Based on the excerpt, describe the obstacles t...                    1
# 8890  Based on the excerpt, describe the obstacles t...                    1
#
#                                             source_text  grade_7  grade_8  \
# 8886  When the Empire State Building was conceived, ...        0        0
# 8887  When the Empire State Building was conceived, ...        0        0
# 8888  When the Empire State Building was conceived, ...        0        0
# 8889  When the Empire State Building was conceived, ...        0        0
# 8890  When the Empire State Building was conceived, ...        0        0
#
#       grade_10  misspelt  correct  length  lexical_diversity
# 8886         1         6      116     123               1.37
# 8887         1        11      169     180               1.55
# 8888         1         4      162     169               1.62
# 8889         1        18      175     199               1.69
# 8890         1         4      158     162               1.74

# %% [markdown]
# 10.7.1. How to measure lexical diversity
# One simple statistic for a text is to find the ratio of total words to unique words, or word tokens divided by word types. This is simple enough for you to calculate – with the caveat of insuring real number (float) division – as long as you filter out the punctuation. Oh, and you should round the resulting floating point numbers to two decimal places, otherwise Python returns it to fourteen decimal places:

# %% [markdown]
# Now you might suspect that the lexical diversity of text could be proportional to how long the text is. The longer the text, the greater the chance for the author to use words that she has not used yet. You can test this hypothesis by plotting lexical diversity against the length of the texts. That, the length of the texts is the independent variable, on the X axis, against which you want to evaluate the lexical diversity of a text, the dependent variable on the Y axis. As the terminology suggests, the dependent variable depends on the independent one, which is shown quantitatively by plotting Y onto X.

# %%
import spacy
nlp = spacy.load('en_core_web_md')

# %%
# number of sentences

def get_number_of_sentences(df):
    """
    Function that returns the number of sentences
    in the document. Could be useful for run-on sentences
    """
    
    _byRow_sents = []
    for essay in df['essay']:
        sents = []
        parsed_essay = nlp(essay)
        for num, sentence in enumerate(parsed_essay.sents):
            sents.append(sentence)
        
        _byRow_sents.append(len(sents))
        
    return df.assign(n_sentences = _byRow_sents)

# %%
essays = get_number_of_sentences(essays)
# essays.head()
# Out:
#       essay_id  essay_set                                              essay  \
# 8886     14834          6  There were many obstacles that the builders fa...
# 8887     14835          6  Him from the start, there would have been many...
# 8888     14836          6  The builders of the Empire State Building face...
# 8889     14837          6  In the passage The Mooring Mast by Marcia Amid...
# 8890     14838          6  The builders of the Empire State Building face...
#
#       rater1_domain1  rater2_domain1  domain1_score  \
# 8886             2.0             2.0            2.0
# 8887             3.0             3.0            3.0
# 8888             3.0             4.0            4.0
# 8889             1.0             1.0            1.0
# 8890             3.0             3.0            3.0
#
#                                                  prompt  has_source_material  \
# 8886  Based on the excerpt, describe the obstacles t...                    1
# 8887  Based on the excerpt, describe the obstacles t...                    1
# 8888  Based on the excerpt, describe the obstacles t...                    1
# 8889  Based on the excerpt, describe the obstacles t...                    1
# 8890  Based on the excerpt, describe the obstacles t...                    1
#
#                                             source_text  grade_7  grade_8  \
# 8886  When the Empire State Building was conceived, ...        0        0
# 8887  When the Empire State Building was conceived, ...        0        0
# 8888  When the Empire State Building was conceived, ...        0        0
# 8889  When the Empire State Building was conceived, ...        0        0
# 8890  When the Empire State Building was conceived, ...        0        0
#
#       grade_10  misspelt  correct  length  lexical_diversity  n_sentences
# 8886         1         6      116     123               1.37            9
# 8887         1        11      169     180               1.55            9
# 8888         1         4      162     169               1.62            8
# 8889         1        18      175     199               1.69           11
# 8890         1         4      158     162               1.74           11

# %%
def get_list_of_number_of_pos(df):
    
    pos = []
    
    for essay in df['essay']:
        parsed_essay = nlp(essay)
        token_pos = [token.pos_ for token in parsed_essay]
        
        pos.append((token_pos.count('NOUN'), token_pos.count('VERB'), token_pos.count('ADV'), token_pos.count('ADJ')))
        
    
    return pos

# %%
pos_list = get_list_of_number_of_pos(essays)

# %%
nouns, verbs, adverbs, adjectives = zip(*pos_list)

# %%
essays = essays.assign(nouns = nouns)
# essays.head()
# Out:
#       essay_id  essay_set                                              essay  \
# 8886     14834          6  There were many obstacles that the builders fa...
# 8887     14835          6  Him from the start, there would have been many...
# 8888     14836          6  The builders of the Empire State Building face...
# 8889     14837          6  In the passage The Mooring Mast by Marcia Amid...
# 8890     14838          6  The builders of the Empire State Building face...
#
#       rater1_domain1  rater2_domain1  domain1_score  \
# 8886             2.0             2.0            2.0
# 8887             3.0             3.0            3.0
# 8888             3.0             4.0            4.0
# 8889             1.0             1.0            1.0
# 8890             3.0             3.0            3.0
#
#                                                  prompt  has_source_material  \
# 8886  Based on the excerpt, describe the obstacles t...                    1
# 8887  Based on the excerpt, describe the obstacles t...                    1
# 8888  Based on the excerpt, describe the obstacles t...                    1
# 8889  Based on the excerpt, describe the obstacles t...                    1
# 8890  Based on the excerpt, describe the obstacles t...                    1
#
#                                             source_text  grade_7  grade_8  \
# 8886  When the Empire State Building was conceived, ...        0        0
# 8887  When the Empire State Building was conceived, ...        0        0
# 8888  When the Empire State Building was conceived, ...        0        0
# 8889  When the Empire State Building was conceived, ...        0        0
# 8890  When the Empire State Building was conceived, ...        0        0
#
#       grade_10  misspelt  correct  length  lexical_diversity  n_sentences  \
# 8886         1         6      116     123               1.37            9
# 8887         1        11      169     180               1.55            9
# 8888         1         4      162     169               1.62            8
# 8889         1        18      175     199               1.69           11
# 8890         1         4      158     162               1.74           11
#
#       nouns
# 8886     29
# 8887     43
# 8888     41
# 8889     36
# 8890     38

# %%
essays = essays.assign(verbs = verbs)
essays = essays.assign(adverbs = adverbs)
essays = essays.assign(adjectives = adjectives)
essays.head()
# Out:
#       essay_id  essay_set                                              essay  \
# 8886     14834          6  There were many obstacles that the builders fa...
# 8887     14835          6  Him from the start, there would have been many...
# 8888     14836          6  The builders of the Empire State Building face...
# 8889     14837          6  In the passage The Mooring Mast by Marcia Amid...
# 8890     14838          6  The builders of the Empire State Building face...
#
#       rater1_domain1  rater2_domain1  domain1_score  \
# 8886             2.0             2.0            2.0
# 8887             3.0             3.0            3.0
# 8888             3.0             4.0            4.0
# 8889             1.0             1.0            1.0
# 8890             3.0             3.0            3.0
#
#                                                  prompt  has_source_material  \
# 8886  Based on the excerpt, describe the obstacles t...                    1
# 8887  Based on the excerpt, describe the obstacles t...                    1
# 8888  Based on the excerpt, describe the obstacles t...                    1
# 8889  Based on the excerpt, describe the obstacles t...                    1
# 8890  Based on the excerpt, describe the obstacles t...                    1
#
#                                             source_text  grade_7  ...  \
# 8886  When the Empire State Building was conceived, ...        0  ...
# 8887  When the Empire State Building was conceived, ...        0  ...
# 8888  When the Empire State Building was conceived, ...        0  ...
# 8889  When the Empire State Building was conceived, ...        0  ...
# 8890  When the Empire State Building was conceived, ...        0  ...
#
#       grade_10  misspelt  correct  length  lexical_diversity  n_sentences  \
# 8886         1         6      116     123               1.37            9
# 8887         1        11      169     180               1.55            9
# 8888         1         4      162     169               1.62            8
# 8889         1        18      175     199               1.69           11
# 8890         1         4      158     162               1.74           11
#
#       nouns  verbs  adverbs  adjectives
# 8886     29     22        9           9
# 8887     43     35       15          13
# 8888     41     35       12           9
# 8889     36     38        8           4
# 8890     38     34       10          13
#
# [5 rows x 21 columns]

# %%
import urllib.request
from bs4 import BeautifulSoup

f = open('../data/intermediate/out.txt','w')

url = "https://satvocabulary.us/"
page = urllib.request.urlopen(url)

soup = BeautifulSoup(page)

# %%
soup.unicode

# %%
import re
regex = re.compile(".*?\((.*?)\)")
result = re.sub("[\(\[].*?[\)\]]", "", 'venal(ity)')

tab = soup.find("table",{"class":"WORDLIST"})
# tab
rows = tab.find_all('tr')
rows

top500SATWords = []

for row in rows:
    data = row.find_all("td")
    
    top500SATWords.append(re.sub("[\(\[].*?[\)\]]", "", ((data[1].get_text()).split(', ')[0])))

# top500SATWords

# %%
# token_lemma

# %%
top500SATWords.pop(0)
top500SATWords
# Out:
# ['abate',
#  'aberration',
#  'abhor',
#  'abstruse',
#  'accost',
#  'acrimony',
#  'acumen',
#  'adamant',
#  'adept',
#  'adroit',
#  'affected',
#  'alacrity',
#  'allocate',
#  'altruistic',
#  'amenable',
#  'amiable',
#  'amicable',
#  'antediluvian',
#  'anthropology',
#  'antipathy',
#  'apathetic',
#  'apt',
#  'arcane',
#  'ascendancy',
#  'ascetic',
#  'aspire',
#  'assail',
#  'assiduous',
#  'assuage',
#  'atrophy',
#  'attenuate',
#  'august',
#  'aura',
#  'auspicious',
#  'autocrat',
#  'automaton',
#  'avarice',
#  'banal',
#  'barrage',
#  'belie',
#  'belligerent',
#  'benevolent',
#  'bequeath',
#  'berate',
#  'bipartisanship',
#  'blighted',
#  'bog',
#  'bolster',
#  'bombastic',
#  'boorish',
#  'buoyant',
#  'burgeon',
#  'buttress',
#  'byzantine',
#  'cacophonous',
#  'cajole',
#  'callous',
#  'cantankerous',
#  'capricious',
#  'castigate',
#  'caustic',
#  'censorious',
#  'censure',
#  'cerebral',
#  'chagrin',
#  'charlatan',
#  'chastise',
#  'chide',
#  'churlish',
#  'circuitous',
#  'circumscribe',
#  'circumvent',
#  'clandestine',
#  'coalesce',
#  'compendious',
#  'complacency',
#  'compliant',
#  'conciliate',
#  'concur',
#  'conflagration',
#  'confluence',
#  'congenial',
#  'conscientious',
#  'consternation',
#  'contempt',
#  'contemptible',
#  'contentious',
#  'convivial',
#  'copious',
#  'corroborate',
#  'cosmopolitan',
#  'credulity',
#  'culpable',
#  'cursory',
#  'dauntless',
#  'dearth',
#  'debacle',
#  'debilitate',
#  'debunk',
#  'decimate',
#  'decorum',
#  'deference',
#  'degradation',
#  'deleterious',
#  'delineate',
#  'demonstrative',
#  'demure',
#  'demystify',
#  'denigrate',
#  'depose',
#  'depravity',
#  'deprecate',
#  'depreciation',
#  'deride',
#  'derivative',
#  'derogatory',
#  'desecration',
#  'despondent',
#  'despot',
#  'destitute',
#  'deterrent',
#  'devoid',
#  'didactic',
#  'diffident',
#  'diffuse',
#  'digress',
#  'dilatory',
#  'diminutive',
#  'dire',
#  'discern',
#  'discomfited',
#  'discount ',
#  'disheartening',
#  'disillusionment',
#  'disingenuous',
#  'disparage',
#  'dispassionate',
#  'dispel',
#  'disputatious',
#  'disquiet',
#  'disseminate',
#  'distaste',
#  'divergent',
#  'divisive',
#  'divulge',
#  'doctrine',
#  'dogmatic',
#  'dormant',
#  'dupe',
#  'duplicitous',
#  'ebullient',
#  'eclectic',
#  'efface',
#  'effervesce',
#  'egalitarian',
#  'elated',
#  'elicit',
#  'elucidate',
#  'elude',
#  'elusive',
#  'embitter',
#  'embroil',
#  'empathetic',
#  'empiric',
#  'encompass',
#  'encroaching',
#  'encumbrance',
#  'enigma',
#  'enumerate',
#  'ephemeral',
#  'epiphany',
#  'epitome',
#  'equanimity',
#  'equitable',
#  'equivocal',
#  'erudite',
#  'esoteric',
#  'estrange',
#  'eulogy',
#  'evoke',
#  'exacting',
#  'excavate',
#  'exemplar',
#  'exhibitionist',
#  'exhort',
#  'exorbitant',
#  'expedient',
#  'exposé',
#  'extol',
#  'extricate',
#  'facile',
#  'faction',
#  'fallacious',
#  'fallacy',
#  'fanaticism',
#  'fastidious',
#  'fathom ',
#  'felicitous',
#  'finesse',
#  'flagrant',
#  'flippant',
#  'florid',
#  'flummox',
#  'folly',
#  'foolhardy',
#  'forlorn',
#  'fortitude',
#  'fortuitous',
#  'fraudulent',
#  'frugal',
#  'furor',
#  'furtive',
#  'futile',
#  'gait',
#  'gallant',
#  'gargantuan',
#  'garish',
#  'genial',
#  'germinate',
#  'glutton',
#  'grandiose',
#  'hackneyed',
#  'hamper ',
#  'hardy',
#  'hasten',
#  'heresy',
#  'histrionic',
#  'hubris',
#  'idiosyncracy',
#  'idyllic',
#  'ignominy',
#  'illicit',
#  'impasse',
#  'imperious',
#  'impetuous',
#  'impudence',
#  'inane',
#  'incongruity',
#  'incredulous',
#  'incriminate',
#  'incubate',
#  'indeterminate',
#  'indict',
#  'indigenous',
#  'indignant',
#  'indiscriminate',
#  'indolent',
#  'indomitable',
#  'induce',
#  'indulgent',
#  'ineffable',
#  'ineptitude',
#  'inert',
#  'ingenuous',
#  'inherent',
#  'inhibit',
#  'innate',
#  'innocuous',
#  'innuendo',
#  'inscrutable',
#  'insipid',
#  'insolence',
#  'instigate',
#  'insular',
#  'intrepid',
#  'inundate',
#  'invoke',
#  'irate',
#  'irony',
#  'irreverent',
#  'jaded',
#  'jocular',
#  'jovial',
#  'judicious',
#  'lackadaisical',
#  'laconic',
#  'laggard',
#  'languid',
#  'latent',
#  'laud',
#  'listless',
#  'lithe',
#  'lucid',
#  'lucrative',
#  'lull',
#  'lurid',
#  'luxuriant',
#  'magnanimity',
#  'malleable',
#  'marred',
#  'maudlin',
#  'melancholy',
#  'mercenary',
#  'mercurial',
#  'miserly',
#  'mitigate',
#  'modicum',
#  'morose',
#  'motley',
#  'multifarious',
#  'nebulous',
#  'nefarious',
#  'neophyte',
#  'notoriety',
#  'noxious',
#  'nuance',
#  'obdurate',
#  'obstinate ',
#  'officious',
#  'onerous',
#  'opportunist',
#  'oracle',
#  'orthodox',
#  'ostensible',
#  'oversight',
#  'pacifist',
#  'pacify',
#  'painstaking',
#  'palliate',
#  'paradigm',
#  'parch',
#  'parody',
#  'partisan',
#  'patronize',
#  'paucity',
#  'pedant',
#  'peevish',
#  'penchant',
#  'penurious',
#  'peremptory',
#  'perfunctory',
#  'peripheral',
#  'perquisite',
#  'petulant',
#  'philanthropist',
#  'piety',
#  'placate',
#  'placid',
#  'plasticity',
#  'plausible',
#  'plethora',
#  'pliable',
#  'polemical',
#  'prattle',
#  'precarious',
#  'precipitate',
#  'preclude',
#  'precocious',
#  'presumptuous',
#  'pretext',
#  'prevaricator',
#  'procure',
#  'prodigious',
#  'profound',
#  'profuse',
#  'prohibitive',
#  'proliferate',
#  'prolific',
#  'pronouncement',
#  'propensity',
#  'proponent',
#  'prosaic',
#  'prospective',
#  'provident',
#  'provincial',
#  'punctilious',
#  'pundit',
#  'quell',
#  'quixotic',
#  'rampant',
#  'ramshackle',
#  'rancor',
#  'rapport',
#  'ratify',
#  'raucous',
#  'ravenous',
#  'raze',
#  'reap',
#  'rebuttal',
#  'recalcitrant',
#  'recant',
#  'recessive',
#  'recluse',
#  'rectify',
#  'redolent',
#  'refutation',
#  'regressive',
#  'relegate',
#  'relinquish',
#  'renounce',
#  'repertory',
#  'reprehensible',
#  'reprimand',
#  'reproach',
#  'repudiate',
#  'repugnant',
#  'rescind',
#  'reticent',
#  'reverent',
#  'rhetoric',
#  'rouse',
#  'sage',
#  'sanctimonious',
#  'sanction ',
#  'sanctity',
#  'sanguine',
#  'satiate',
#  'satire',
#  'saturate',
#  'scanty',
#  'scathing',
#  'scintillating',
#  'scope',
#  'scrupulous',
#  'scrutinize',
#  'self-righteous',
#  'self-serving',
#  'serendipity',
#  'servile',
#  'shrewd',
#  'shroud',
#  'simile',
#  'slight ',
#  'slipshod',
#  'solace',
#  'solicitous',
#  'somber',
#  'sophistry',
#  'spartan',
#  'sporadic',
#  'spurious',
#  'spurn',
#  'squander',
#  'stagnant',
#  'stark',
#  'static ',
#  'staunch',
#  'steadfast',
#  'stock ',
#  'strident',
#  'stupefy',
#  'subservient',
#  'substantiate',
#  'subversive',
#  'succulent',
#  'supercilious',
#  'superfluous',
#  'supplant',
#  'surfeit',
#  'susceptible',
#  'sycophant',
#  'tangential',
#  'teem',
#  'temperamental',
#  'temporize',
#  'tenacious',
#  'tenuous',
#  'tirade',
#  'toady',
#  'torpor',
#  'totalitarian',
#  'tout',
#  'tractable',
#  'transient',
#  'treatise',
#  'trepidation',
#  'tribulation',
#  'trifling',
#  'trite',
#  'truculent',
#  'ubiquitous',
#  'unabashed',
#  'uncanny',
#  'uncouth',
#  'unfathomable',
#  'ungainly',
#  'unruly',
#  'unwitting',
#  'urbane',
#  'usurp',
#  'vacuous',
#  'vanquish',
#  'vapid',
#  'venal',
#  'venerable',
#  'verbose',
#  'vicarious',
#  'vigilant',
#  'vindicate',
#  'vindictive',
#  'virtuoso',
#  'virulent',
#  'viscous',
#  'vocation',
#  'vying',
#  'waning',
#  'wayward',
#  'wrath',
#  'wry',
#  'zealot']

# %%
top500_joined = ' '.join(str(v) for v in top500SATWords)

# %%
token_lemma_top500 = [token.lemma_ for token in nlp(top500_joined)]

# %%
# token_lemma_top500

# %%
# print(len(token_lemma))
print(len(token_lemma_top500))
# Out:
# 512

# %%
# list1 = ['car', 'garden', 'cement', 'chicken']
# list2 = ['automobile', 'nest', 'cementry', 'house']

# c = sum(el in list1 for el in list2)
# c

# %%
# n_top500SAT = sum(el in token_lemma for el in token_lemma_top500)

# %%
# n_top500SAT

# %%
def calculate_number_of_top500_SAT_words(parsed_essay, list_of_word_to_check_against):
    list_of_word_to_check_against = sorted(list(set(list_of_word_to_check_against)))
    token_attributes = [(token.lemma_, token.is_stop, token.is_punct) for token in parsed_essay]
    
    df = pd.DataFrame(token_attributes, columns=['text', 'stop', 'punctuation'])
    df2 = df[df['stop'] != True]
    df3 = df2[df2['punctuation'] != True]
    
    low = df3['text'].tolist()
    low  = [word.lower() for word in low]
    
    count = sum(el in low for el in list_of_word_to_check_against)
    return count

# %%
# calculate_number_of_top500_SAT_words(set(parsed_essay), token_lemma_top500)
# Out:
# 0

# %%
# print(token_lemma_top500)

# %%
# print(set(list1))
# print(bool(set(list1) & set(list2)))

# %%
# smth = set(list1) & set(list2)

# %%
# smth

# %%
def buildDFSAT(df):
    n_top500 = []
    for essay in df['essay']:
        
        parsed_essay = nlp(essay)
        n_top500.append(calculate_number_of_top500_SAT_words(parsed_essay, token_lemma_top500))        
    
    essays = df.assign(n_top500 = n_top500) 
    return essays
        
essays = buildDFSAT(essays)
essays.head()

# %% [markdown]
# Fragments
# The sentences you have encountered so far have been independent clauses. As you look more closely at your past writing assignments, you may notice that some of your sentences are not complete. A sentence that is missing a subject or a verb is called a fragment. A fragment may include a description or may express part of an idea, but it does not express a complete thought.
#
# Fragment: Children helping in the kitchen.
#
# Complete sentence: Children helping in the kitchen often make a mess.
#
# You can easily fix a fragment by adding the missing subject or verb. In the example, the sentence was missing a verb. Adding often make a mess creates an S-V-N sentence structure.
#
# Figure 1.1 Editing Fragments That Are Missing a Subject or a Verb
#
#
#
# See whether you can identify what is missing in the following fragments.
#
# Fragment: Told her about the broken vase.
#
# Complete sentence: I told her about the broken vase.
#
# Fragment: The store down on Main Street.
#
# Complete sentence: The store down on Main Street sells music.

# %%
essays.iloc[0, 2]
# Out:
# "There were many obstacles that the builders faced in attempting to have dirigibles dock at the Empire State Building. Safety was an issue with the dirigibles because of the highly flammable gas hydrogen. So, if the dirigibles explode over New York many people could be killed in the very populated. Another problem is keeping the derigible @CAPS1 so people can get off while the wind moves the back end of itself. The only way was to tie lead weights down in the back of the dirigible, but it would be dangerous over people down below. So, these obstacles workers faced, never got past them and so they made the world's highest soda fountain and tea garden for tourists in the observation area."

# %%
sample = nlp(essays.iloc[0, 2])

# %%
token_dep = [token.dep_ for token in sample]

# %%
from spacy import displacy

for num, sentence in enumerate(sample.sents):
    if (num < 2):
        print('Sentence #{}'.format(num))
        print(sentence)
        print(' ')
        
#         displacy.render(sentence, style="dep")
        token_dep0 = [token.dep_ for token in sentence]
        print(token_dep0)
# Out:
# Sentence #0
# There were many obstacles that the builders faced in attempting to have dirigibles dock at the Empire State Building.
#
# ['expl', 'ROOT', 'amod', 'attr', 'dobj', 'det', 'nsubj', 'relcl', 'prep', 'pcomp', 'aux', 'xcomp', 'nsubj', 'ccomp', 'prep', 'det', 'compound', 'compound', 'pobj', 'punct']
# Sentence #1
# Safety was an issue with the dirigibles because of the highly flammable gas hydrogen.
#
# ['nsubj', 'ROOT', 'det', 'attr', 'prep', 'det', 'pobj', 'prep', 'pcomp', 'det', 'advmod', 'amod', 'compound', 'pobj', 'punct']

# %%
sample2 = nlp('I have')
token_dep1 = [token.dep_ for token in sample2]
token_dep1
# Out:
# ['nsubj', 'ROOT']

# %%
# https://github.com/clir/clearnlp-guidelines/blob/master/md/specifications/dependency_labels.md

objects = ['dobj', 'dative', 'attr', 'oprd']

subjects = ['nsubj', 'nsubjpass', 'csubj', 'csubjpass', 'agent', 'expl']

verbs = []

# %%
essays = essays.drop(['essay_set', 'essay', 'rater1_domain1', 'rater2_domain1', 'prompt', 'has_source_material', 'source_text', 'grade_7', 'grade_8', 'grade_10'], axis=1)
essays.to_csv('../data/processed/essays_model_2.csv')
